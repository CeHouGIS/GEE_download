# %%
import pandas as pd
from glob import glob
import os 
from tqdm import tqdm
import geopandas as gpd
import numpy as np

data = pd.read_csv("/code/GEE_download/human_settlement_grid_cells_deg_25.csv")

# %%
years = pd.DataFrame({'year': range(2008, 2025)})
data['key'] = 1
years['key'] = 1

data = pd.merge(data, years, on='key', how='outer').drop('key', axis=1)
data['time_start'] = data['year'].astype(str) + '-01-01'
data['time_end'] = data['year'].astype(str) + '-12-31'
# data['download_command'] = data.apply(lambda row: f"grid_{row.name}|{row['lon_min']},{row['lat_min']}|{row['lon_max']},{row['lat_max']}|14|{row['time_start']}|12", axis=1)
data.head()
# Out:
#    lon_min  lat_min  lon_max  lat_max      value  year  time_start    time_end
# 0    167.5    -47.5    170.0    -45.0  18.451653  2008  2008-01-01  2008-12-31
# 1    167.5    -47.5    170.0    -45.0  18.451653  2009  2009-01-01  2009-12-31
# 2    167.5    -47.5    170.0    -45.0  18.451653  2010  2010-01-01  2010-12-31
# 3    167.5    -47.5    170.0    -45.0  18.451653  2011  2011-01-01  2011-12-31
# 4    167.5    -47.5    170.0    -45.0  18.451653  2012  2012-01-01  2012-12-31

# %%
data
# Out:
#        lon_min  lat_min  lon_max  lat_max      value  year  time_start  \
# 0        167.5    -47.5    170.0    -45.0  18.451653  2008  2008-01-01
# 1        167.5    -47.5    170.0    -45.0  18.451653  2009  2009-01-01
# 2        167.5    -47.5    170.0    -45.0  18.451653  2010  2010-01-01
# 3        167.5    -47.5    170.0    -45.0  18.451653  2011  2011-01-01
# 4        167.5    -47.5    170.0    -45.0  18.451653  2012  2012-01-01
# ...        ...      ...      ...      ...        ...   ...         ...
# 18933    160.0     67.5    162.5     70.0   2.504991  2020  2020-01-01
# 18934    160.0     67.5    162.5     70.0   2.504991  2021  2021-01-01
# 18935    160.0     67.5    162.5     70.0   2.504991  2022  2022-01-01
# 18936    160.0     67.5    162.5     70.0   2.504991  2023  2023-01-01
# 18937    160.0     67.5    162.5     70.0   2.504991  2024  2024-01-01
#
#          time_end
# 0      2008-12-31
# 1      2009-12-31
# 2      2010-12-31
# 3      2011-12-31
# 4      2012-12-31
# ...           ...
# 18933  2020-12-31
# 18934  2021-12-31
# 18935  2022-12-31
# 18936  2023-12-31
# 18937  2024-12-31
#
# [18938 rows x 8 columns]

# %%
import json
import numpy as np
import os
import pandas as pd

# kenya_bound = [33.89, -4.68, 41.86, 5.51] # [west, south, east, north] bounds of Kenya
# bound = [2, 4, 16, 14] # [west, south, east, north] bounds 
# bound = [-20, 0, 10, 50]

# bound = [120,30,122.25,32] # [west, south, east, north] bounds of Shanghai
save_name = f"Africa_all_2008_2024"
os.makedirs(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata', exist_ok=True)


# Create grid cells of 0.25x0.25 degree
# lon_min, lat_min, lon_max, lat_max = bound
# lons = np.arange(lon_min, lon_max + 0.25, 0.25)
# lats = np.arange(lat_min, lat_max + 0.25, 0.25)

if not os.path.exists(f'/code/GEE_download/{save_name}/{save_name}_grid_cells.json'):
    grid_dict = {}
    for i, row in data.iterrows():
        lon_min = row['lon_min']
        lat_min = row['lat_min']
        lon_max = row['lon_max']
        lat_max = row['lat_max']
        cell_name = f"{save_name}_grid_{i // (2024 - 2008 + 1)}_{row['time_start'][:4]}"
        grid_dict[cell_name] = {
            "lon_min": f"{float(lon_min):.4f}",
            "lon_max": f"{float(lon_max):.4f}",
            "lat_min": f"{float(lat_min):.4f}",
            "lat_max": f"{float(lat_max):.4f}",
            "start_time": row['time_start'],
            "end_time": row['time_end']
        }

    # Save the grid cells as a JSON file
    with open(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}.json', 'w') as f:
        json.dump(grid_dict, f, indent=4)

    print(f"Created {len(grid_dict)} grid cells and saved to {save_name}.json")

else:
    grid_dict = json.load(open(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}.json', 'r'))
pd.DataFrame(grid_dict).T.reset_index().rename(columns={'index':'grid_name'}).to_csv(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}_grid_cells.csv', index=False)
# Out:
# Created 18938 grid cells and saved to Africa_all_2008_2024.json

# %%
def generate_code_script(batch_size, save_name, grid_dict, mode='python'):
    regions = []
    for cell_name, coords in grid_dict.items():
        region = {
            'name': cell_name,
            'geometry': f"ee.Geometry.Rectangle([{coords['lon_min']}, {coords['lat_min']}, {coords['lon_max']}, {coords['lat_max']}])"
        }
        regions.append(region)

    if mode == "GEE":
        gee_code = """// =================================================================================
        // **第二步：设置通用的参数**
        // =================================================================================

        // 加载影像集合
        var dataset = ee.ImageCollection('GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL');

        // 开始和结束时间
        var date_s = '2023-01-01';
        var date_e = '2024-01-01';

        // 下载分辨率
        var resolution = 10;

        // 可视化参数
        var visParams = {min: -0.3, max: 0.3, bands: ['A01', 'A16', 'A09']};


        // =================================================================================
        // **第三步：循环遍历每个区域并创建导出任务**
        // =================================================================================

        // 使用 forEach 循环来处理 'regions' 列表中的每一个元素
        regions.forEach(function(region) {

            // 1. 筛选影像
            // 注意：这里的 filterBounds 使用的是当前循环中的 region.geometry
            var image = dataset
            .filterDate(date_s, date_e)
            .filterBounds(region.geometry)
            .first();

            // 2. 在地图上显示影像（可选，方便检查）
            // 为了区分，我们用区域的名字来命名图层
            Map.addLayer(image, visParams, region.name + ' embeddings');
            Map.centerObject(region.geometry, 10); // 将地图中心移动到当前区域

            // 3. 为当前区域创建导出任务
            Export.image.toDrive({
            image: image,
            // 在描述和文件名中加入区域名称，以保证每个任务和文件都独一无二
            description: 'Satellite_Embedding_' + region.name,
            folder: 'GEE_Exports', // Google Drive 中的文件夹
            fileNamePrefix: 'Satellite_Embedding_' + region.name, // 文件名前缀
            scale: resolution,
            region: region.geometry, // 使用当前循环中的区域范围
            maxPixels: 1e13
            });
        });"""


        # Format the output in JavaScript syntax for Earth Engine
        js_regions = "var regions = [\n"
        for region in regions:
            js_regions += f"  {{\n"
            js_regions += f"    name: '{region['name']}',\n"
            js_regions += f"    geometry: {region['geometry']}\n"
            js_regions += f"    'time_start': '{grid_dict[region['name']]['time_start']}',\n"
            js_regions += f"    'time_end': '{grid_dict[region['name']]['end_time']}'\n"
            js_regions += f"  }},\n"
        js_regions += "];"

        
        batched_regions = []
        for i in range(0, len(regions), batch_size):
            batch = regions[i:i+batch_size]
            batched_regions.append(batch)

        # Create separate JavaScript files for each batch
        for batch_idx, batch in enumerate(batched_regions):
            batch_js = "var regions = [\n"
            for region in batch:
                batch_js += f"  {{\n"
                batch_js += f"    name: '{region['name']}',\n"
                batch_js += f"    geometry: {region['geometry']},\n"
                batch_js += f"    time_start: '{grid_dict[region['name']]['start_time']}',\n"
                batch_js += f"    time_end: '{grid_dict[region['name']]['end_time']}'\n"
                batch_js += f"  }},\n"
            batch_js += "];" + "\n" + "\n" + gee_code

            # Create the directory if it doesn't exist
            os.makedirs(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}_download_GEE', exist_ok=True)
            # Save each batch to a separate file
            with open(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}_download_GEE/{save_name}_regions_batch_{batch_idx+1}.txt', 'w') as f:
                f.write(batch_js)

            print(f"Batch {batch_idx+1} with {len(batch)} regions saved to {save_name}_regions_batch_{batch_idx+1}.txt")
            print(f"Generated {len(regions)} regions for Earth Engine")


    elif mode=="python":
        js_regions = "var regions = [\n"
        for region in regions:
            js_regions += f"  {{\n"
            js_regions += f"    'name': '{region['name']}',\n"
            js_regions += f"    'geometry': {region['geometry']}\n"
            js_regions += f"    'time_start': '{grid_dict[region['name']]['start_time']}',\n"
            js_regions += f"    'time_end': '{grid_dict[region['name']]['end_time']}'\n"
            js_regions += f"  }},\n"
        js_regions += "]"


        # Split regions into groups of 25
        batched_regions = []
        for i in range(0, len(regions), batch_size):
            batch = regions[i:i+batch_size]
            batched_regions.append(batch)

            # os.makedirs(f'/code/GEE_download/{save_name}/{save_name}_download_python/', exist_ok=True)

            json_batch = [
                {
                    "name": region["name"],
                    "geometry": region["geometry"],
                    "time_start": grid_dict[region['name']]['start_time'],
                    "time_end": grid_dict[region['name']]['end_time']
                }
                for region in batch
            ]
            os.makedirs(f"/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}_download_python/", exist_ok=True)
            with open(f'/nas/houce/Alphaearth_embedding/GEE_extracted/{save_name}/metadata/{save_name}_download_python/{save_name}_regions_batch_{i//batch_size+1}.json', 'w', encoding='utf-8') as f_json:
                json.dump(json_batch, f_json, ensure_ascii=False, indent=4)
            print(f"Batch {i//batch_size+1} with {len(batch)} regions saved to {save_name}_regions_batch_{i//batch_size+1}.json")

# save_name = f"Africa_grid_{bound[0]}_{bound[1]}_{bound[2]}_{bound[3]}"
generate_code_script(25, save_name, grid_dict, mode='python')
# Out:
# Batch 1 with 25 regions saved to Africa_all_2008_2024_regions_batch_1.json
# Batch 2 with 25 regions saved to Africa_all_2008_2024_regions_batch_2.json
# Batch 3 with 25 regions saved to Africa_all_2008_2024_regions_batch_3.json
# Batch 4 with 25 regions saved to Africa_all_2008_2024_regions_batch_4.json
# Batch 5 with 25 regions saved to Africa_all_2008_2024_regions_batch_5.json
# Batch 6 with 25 regions saved to Africa_all_2008_2024_regions_batch_6.json
# Batch 7 with 25 regions saved to Africa_all_2008_2024_regions_batch_7.json
# Batch 8 with 25 regions saved to Africa_all_2008_2024_regions_batch_8.json
# Batch 9 with 25 regions saved to Africa_all_2008_2024_regions_batch_9.json
# Batch 10 with 25 regions saved to Africa_all_2008_2024_regions_batch_10.json
# Batch 11 with 25 regions saved to Africa_all_2008_2024_regions_batch_11.json
# Batch 12 with 25 regions saved to Africa_all_2008_2024_regions_batch_12.json
# Batch 13 with 25 regions saved to Africa_all_2008_2024_regions_batch_13.json
# Batch 14 with 25 regions saved to Africa_all_2008_2024_regions_batch_14.json
# Batch 15 with 25 regions saved to Africa_all_2008_2024_regions_batch_15.json
# Batch 16 with 25 regions saved to Africa_all_2008_2024_regions_batch_16.json
# Batch 17 with 25 regions saved to Africa_all_2008_2024_regions_batch_17.json
# Batch 18 with 25 regions saved to Africa_all_2008_2024_regions_batch_18.json
# Batch 19 with 25 regions saved to Africa_all_2008_2024_regions_batch_19.json
# Batch 20 with 25 regions saved to Africa_all_2008_2024_regions_batch_20.json
# Batch 21 with 25 regions saved to Africa_all_2008_2024_regions_batch_21.json
# Batch 22 with 25 regions saved to Africa_all_2008_2024_regions_batch_22.json
# Batch 23 with 25 regions saved to Africa_all_2008_2024_regions_batch_23.json
# Batch 24 with 25 regions saved to Africa_all_2008_2024_regions_batch_24.json
# Batch 25 with 25 regions saved to Africa_all_2008_2024_regions_batch_25.json
# Batch 26 with 25 regions saved to Africa_all_2008_2024_regions_batch_26.json
# Batch 27 with 25 regions saved to Africa_all_2008_2024_regions_batch_27.json
# Batch 28 with 25 regions saved to Africa_all_2008_2024_regions_batch_28.json
# Batch 29 with 25 regions saved to Africa_all_2008_2024_regions_batch_29.json
# Batch 30 with 25 regions saved to Africa_all_2008_2024_regions_batch_30.json
# Batch 31 with 25 regions saved to Africa_all_2008_2024_regions_batch_31.json
# Batch 32 with 25 regions saved to Africa_all_2008_2024_regions_batch_32.json
# Batch 33 with 25 regions saved to Africa_all_2008_2024_regions_batch_33.json
# Batch 34 with 25 regions saved to Africa_all_2008_2024_regions_batch_34.json
# Batch 35 with 25 regions saved to Africa_all_2008_2024_regions_batch_35.json
# Batch 36 with 25 regions saved to Africa_all_2008_2024_regions_batch_36.json
# Batch 37 with 25 regions saved to Africa_all_2008_2024_regions_batch_37.json
# Batch 38 with 25 regions saved to Africa_all_2008_2024_regions_batch_38.json
# Batch 39 with 25 regions saved to Africa_all_2008_2024_regions_batch_39.json
# Batch 40 with 25 regions saved to Africa_all_2008_2024_regions_batch_40.json
# Batch 41 with 25 regions saved to Africa_all_2008_2024_regions_batch_41.json
# Batch 42 with 25 regions saved to Africa_all_2008_2024_regions_batch_42.json
# Batch 43 with 25 regions saved to Africa_all_2008_2024_regions_batch_43.json
# Batch 44 with 25 regions saved to Africa_all_2008_2024_regions_batch_44.json
# Batch 45 with 25 regions saved to Africa_all_2008_2024_regions_batch_45.json
# Batch 46 with 25 regions saved to Africa_all_2008_2024_regions_batch_46.json
# Batch 47 with 25 regions saved to Africa_all_2008_2024_regions_batch_47.json
# Batch 48 with 25 regions saved to Africa_all_2008_2024_regions_batch_48.json
# Batch 49 with 25 regions saved to Africa_all_2008_2024_regions_batch_49.json
# Batch 50 with 25 regions saved to Africa_all_2008_2024_regions_batch_50.json
# Batch 51 with 25 regions saved to Africa_all_2008_2024_regions_batch_51.json
# Batch 52 with 25 regions saved to Africa_all_2008_2024_regions_batch_52.json
# Batch 53 with 25 regions saved to Africa_all_2008_2024_regions_batch_53.json
# Batch 54 with 25 regions saved to Africa_all_2008_2024_regions_batch_54.json
# Batch 55 with 25 regions saved to Africa_all_2008_2024_regions_batch_55.json
# Batch 56 with 25 regions saved to Africa_all_2008_2024_regions_batch_56.json
# Batch 57 with 25 regions saved to Africa_all_2008_2024_regions_batch_57.json
# Batch 58 with 25 regions saved to Africa_all_2008_2024_regions_batch_58.json
# Batch 59 with 25 regions saved to Africa_all_2008_2024_regions_batch_59.json
# Batch 60 with 25 regions saved to Africa_all_2008_2024_regions_batch_60.json
# Batch 61 with 25 regions saved to Africa_all_2008_2024_regions_batch_61.json
# Batch 62 with 25 regions saved to Africa_all_2008_2024_regions_batch_62.json
# Batch 63 with 25 regions saved to Africa_all_2008_2024_regions_batch_63.json
# Batch 64 with 25 regions saved to Africa_all_2008_2024_regions_batch_64.json
# Batch 65 with 25 regions saved to Africa_all_2008_2024_regions_batch_65.json
# Batch 66 with 25 regions saved to Africa_all_2008_2024_regions_batch_66.json
# Batch 67 with 25 regions saved to Africa_all_2008_2024_regions_batch_67.json
# Batch 68 with 25 regions saved to Africa_all_2008_2024_regions_batch_68.json
# Batch 69 with 25 regions saved to Africa_all_2008_2024_regions_batch_69.json
# Batch 70 with 25 regions saved to Africa_all_2008_2024_regions_batch_70.json
# Batch 71 with 25 regions saved to Africa_all_2008_2024_regions_batch_71.json
# Batch 72 with 25 regions saved to Africa_all_2008_2024_regions_batch_72.json
# Batch 73 with 25 regions saved to Africa_all_2008_2024_regions_batch_73.json
# Batch 74 with 25 regions saved to Africa_all_2008_2024_regions_batch_74.json
# Batch 75 with 25 regions saved to Africa_all_2008_2024_regions_batch_75.json
# Batch 76 with 25 regions saved to Africa_all_2008_2024_regions_batch_76.json
# Batch 77 with 25 regions saved to Africa_all_2008_2024_regions_batch_77.json
# Batch 78 with 25 regions saved to Africa_all_2008_2024_regions_batch_78.json
# Batch 79 with 25 regions saved to Africa_all_2008_2024_regions_batch_79.json
# Batch 80 with 25 regions saved to Africa_all_2008_2024_regions_batch_80.json
# Batch 81 with 25 regions saved to Africa_all_2008_2024_regions_batch_81.json
# Batch 82 with 25 regions saved to Africa_all_2008_2024_regions_batch_82.json
# Batch 83 with 25 regions saved to Africa_all_2008_2024_regions_batch_83.json
# Batch 84 with 25 regions saved to Africa_all_2008_2024_regions_batch_84.json
# Batch 85 with 25 regions saved to Africa_all_2008_2024_regions_batch_85.json
# Batch 86 with 25 regions saved to Africa_all_2008_2024_regions_batch_86.json
# Batch 87 with 25 regions saved to Africa_all_2008_2024_regions_batch_87.json
# Batch 88 with 25 regions saved to Africa_all_2008_2024_regions_batch_88.json
# Batch 89 with 25 regions saved to Africa_all_2008_2024_regions_batch_89.json
# Batch 90 with 25 regions saved to Africa_all_2008_2024_regions_batch_90.json
# Batch 91 with 25 regions saved to Africa_all_2008_2024_regions_batch_91.json
# Batch 92 with 25 regions saved to Africa_all_2008_2024_regions_batch_92.json
# Batch 93 with 25 regions saved to Africa_all_2008_2024_regions_batch_93.json
# Batch 94 with 25 regions saved to Africa_all_2008_2024_regions_batch_94.json
# Batch 95 with 25 regions saved to Africa_all_2008_2024_regions_batch_95.json
# Batch 96 with 25 regions saved to Africa_all_2008_2024_regions_batch_96.json
# Batch 97 with 25 regions saved to Africa_all_2008_2024_regions_batch_97.json
# Batch 98 with 25 regions saved to Africa_all_2008_2024_regions_batch_98.json
# Batch 99 with 25 regions saved to Africa_all_2008_2024_regions_batch_99.json
# Batch 100 with 25 regions saved to Africa_all_2008_2024_regions_batch_100.json
# Batch 101 with 25 regions saved to Africa_all_2008_2024_regions_batch_101.json
# Batch 102 with 25 regions saved to Africa_all_2008_2024_regions_batch_102.json
# Batch 103 with 25 regions saved to Africa_all_2008_2024_regions_batch_103.json
# Batch 104 with 25 regions saved to Africa_all_2008_2024_regions_batch_104.json
# Batch 105 with 25 regions saved to Africa_all_2008_2024_regions_batch_105.json
# Batch 106 with 25 regions saved to Africa_all_2008_2024_regions_batch_106.json
# Batch 107 with 25 regions saved to Africa_all_2008_2024_regions_batch_107.json
# Batch 108 with 25 regions saved to Africa_all_2008_2024_regions_batch_108.json
# Batch 109 with 25 regions saved to Africa_all_2008_2024_regions_batch_109.json
# Batch 110 with 25 regions saved to Africa_all_2008_2024_regions_batch_110.json
# Batch 111 with 25 regions saved to Africa_all_2008_2024_regions_batch_111.json
# Batch 112 with 25 regions saved to Africa_all_2008_2024_regions_batch_112.json
# Batch 113 with 25 regions saved to Africa_all_2008_2024_regions_batch_113.json
# Batch 114 with 25 regions saved to Africa_all_2008_2024_regions_batch_114.json
# Batch 115 with 25 regions saved to Africa_all_2008_2024_regions_batch_115.json
# Batch 116 with 25 regions saved to Africa_all_2008_2024_regions_batch_116.json
# Batch 117 with 25 regions saved to Africa_all_2008_2024_regions_batch_117.json
# Batch 118 with 25 regions saved to Africa_all_2008_2024_regions_batch_118.json
# Batch 119 with 25 regions saved to Africa_all_2008_2024_regions_batch_119.json
# Batch 120 with 25 regions saved to Africa_all_2008_2024_regions_batch_120.json
# Batch 121 with 25 regions saved to Africa_all_2008_2024_regions_batch_121.json
# Batch 122 with 25 regions saved to Africa_all_2008_2024_regions_batch_122.json
# Batch 123 with 25 regions saved to Africa_all_2008_2024_regions_batch_123.json
# Batch 124 with 25 regions saved to Africa_all_2008_2024_regions_batch_124.json
# Batch 125 with 25 regions saved to Africa_all_2008_2024_regions_batch_125.json
# Batch 126 with 25 regions saved to Africa_all_2008_2024_regions_batch_126.json
# Batch 127 with 25 regions saved to Africa_all_2008_2024_regions_batch_127.json
# Batch 128 with 25 regions saved to Africa_all_2008_2024_regions_batch_128.json
# Batch 129 with 25 regions saved to Africa_all_2008_2024_regions_batch_129.json
# Batch 130 with 25 regions saved to Africa_all_2008_2024_regions_batch_130.json
# Batch 131 with 25 regions saved to Africa_all_2008_2024_regions_batch_131.json
# Batch 132 with 25 regions saved to Africa_all_2008_2024_regions_batch_132.json
# Batch 133 with 25 regions saved to Africa_all_2008_2024_regions_batch_133.json
# Batch 134 with 25 regions saved to Africa_all_2008_2024_regions_batch_134.json
# Batch 135 with 25 regions saved to Africa_all_2008_2024_regions_batch_135.json
# Batch 136 with 25 regions saved to Africa_all_2008_2024_regions_batch_136.json
# Batch 137 with 25 regions saved to Africa_all_2008_2024_regions_batch_137.json
# Batch 138 with 25 regions saved to Africa_all_2008_2024_regions_batch_138.json
# Batch 139 with 25 regions saved to Africa_all_2008_2024_regions_batch_139.json
# Batch 140 with 25 regions saved to Africa_all_2008_2024_regions_batch_140.json
# Batch 141 with 25 regions saved to Africa_all_2008_2024_regions_batch_141.json
# Batch 142 with 25 regions saved to Africa_all_2008_2024_regions_batch_142.json
# Batch 143 with 25 regions saved to Africa_all_2008_2024_regions_batch_143.json
# Batch 144 with 25 regions saved to Africa_all_2008_2024_regions_batch_144.json
# Batch 145 with 25 regions saved to Africa_all_2008_2024_regions_batch_145.json
# Batch 146 with 25 regions saved to Africa_all_2008_2024_regions_batch_146.json
# Batch 147 with 25 regions saved to Africa_all_2008_2024_regions_batch_147.json
# Batch 148 with 25 regions saved to Africa_all_2008_2024_regions_batch_148.json
# Batch 149 with 25 regions saved to Africa_all_2008_2024_regions_batch_149.json
# Batch 150 with 25 regions saved to Africa_all_2008_2024_regions_batch_150.json
# Batch 151 with 25 regions saved to Africa_all_2008_2024_regions_batch_151.json
# Batch 152 with 25 regions saved to Africa_all_2008_2024_regions_batch_152.json
# Batch 153 with 25 regions saved to Africa_all_2008_2024_regions_batch_153.json
# Batch 154 with 25 regions saved to Africa_all_2008_2024_regions_batch_154.json
# Batch 155 with 25 regions saved to Africa_all_2008_2024_regions_batch_155.json
# Batch 156 with 25 regions saved to Africa_all_2008_2024_regions_batch_156.json
# Batch 157 with 25 regions saved to Africa_all_2008_2024_regions_batch_157.json
# Batch 158 with 25 regions saved to Africa_all_2008_2024_regions_batch_158.json
# Batch 159 with 25 regions saved to Africa_all_2008_2024_regions_batch_159.json
# Batch 160 with 25 regions saved to Africa_all_2008_2024_regions_batch_160.json
# Batch 161 with 25 regions saved to Africa_all_2008_2024_regions_batch_161.json
# Batch 162 with 25 regions saved to Africa_all_2008_2024_regions_batch_162.json
# Batch 163 with 25 regions saved to Africa_all_2008_2024_regions_batch_163.json
# Batch 164 with 25 regions saved to Africa_all_2008_2024_regions_batch_164.json
# Batch 165 with 25 regions saved to Africa_all_2008_2024_regions_batch_165.json
# Batch 166 with 25 regions saved to Africa_all_2008_2024_regions_batch_166.json
# Batch 167 with 25 regions saved to Africa_all_2008_2024_regions_batch_167.json
# Batch 168 with 25 regions saved to Africa_all_2008_2024_regions_batch_168.json
# Batch 169 with 25 regions saved to Africa_all_2008_2024_regions_batch_169.json
# Batch 170 with 25 regions saved to Africa_all_2008_2024_regions_batch_170.json
# Batch 171 with 25 regions saved to Africa_all_2008_2024_regions_batch_171.json
# Batch 172 with 25 regions saved to Africa_all_2008_2024_regions_batch_172.json
# Batch 173 with 25 regions saved to Africa_all_2008_2024_regions_batch_173.json
# Batch 174 with 25 regions saved to Africa_all_2008_2024_regions_batch_174.json
# Batch 175 with 25 regions saved to Africa_all_2008_2024_regions_batch_175.json
# Batch 176 with 25 regions saved to Africa_all_2008_2024_regions_batch_176.json
# Batch 177 with 25 regions saved to Africa_all_2008_2024_regions_batch_177.json
# Batch 178 with 25 regions saved to Africa_all_2008_2024_regions_batch_178.json
# Batch 179 with 25 regions saved to Africa_all_2008_2024_regions_batch_179.json
# Batch 180 with 25 regions saved to Africa_all_2008_2024_regions_batch_180.json
# Batch 181 with 25 regions saved to Africa_all_2008_2024_regions_batch_181.json
# Batch 182 with 25 regions saved to Africa_all_2008_2024_regions_batch_182.json
# Batch 183 with 25 regions saved to Africa_all_2008_2024_regions_batch_183.json
# Batch 184 with 25 regions saved to Africa_all_2008_2024_regions_batch_184.json
# Batch 185 with 25 regions saved to Africa_all_2008_2024_regions_batch_185.json
# Batch 186 with 25 regions saved to Africa_all_2008_2024_regions_batch_186.json
# Batch 187 with 25 regions saved to Africa_all_2008_2024_regions_batch_187.json
# Batch 188 with 25 regions saved to Africa_all_2008_2024_regions_batch_188.json
# Batch 189 with 25 regions saved to Africa_all_2008_2024_regions_batch_189.json
# Batch 190 with 25 regions saved to Africa_all_2008_2024_regions_batch_190.json
# Batch 191 with 25 regions saved to Africa_all_2008_2024_regions_batch_191.json
# Batch 192 with 25 regions saved to Africa_all_2008_2024_regions_batch_192.json
# Batch 193 with 25 regions saved to Africa_all_2008_2024_regions_batch_193.json
# Batch 194 with 25 regions saved to Africa_all_2008_2024_regions_batch_194.json
# Batch 195 with 25 regions saved to Africa_all_2008_2024_regions_batch_195.json
# Batch 196 with 25 regions saved to Africa_all_2008_2024_regions_batch_196.json
# Batch 197 with 25 regions saved to Africa_all_2008_2024_regions_batch_197.json
# Batch 198 with 25 regions saved to Africa_all_2008_2024_regions_batch_198.json
# Batch 199 with 25 regions saved to Africa_all_2008_2024_regions_batch_199.json
# Batch 200 with 25 regions saved to Africa_all_2008_2024_regions_batch_200.json
# Batch 201 with 25 regions saved to Africa_all_2008_2024_regions_batch_201.json
# Batch 202 with 25 regions saved to Africa_all_2008_2024_regions_batch_202.json
# Batch 203 with 25 regions saved to Africa_all_2008_2024_regions_batch_203.json
# Batch 204 with 25 regions saved to Africa_all_2008_2024_regions_batch_204.json
# Batch 205 with 25 regions saved to Africa_all_2008_2024_regions_batch_205.json
# Batch 206 with 25 regions saved to Africa_all_2008_2024_regions_batch_206.json
# Batch 207 with 25 regions saved to Africa_all_2008_2024_regions_batch_207.json
# Batch 208 with 25 regions saved to Africa_all_2008_2024_regions_batch_208.json
# Batch 209 with 25 regions saved to Africa_all_2008_2024_regions_batch_209.json
# Batch 210 with 25 regions saved to Africa_all_2008_2024_regions_batch_210.json
# Batch 211 with 25 regions saved to Africa_all_2008_2024_regions_batch_211.json
# Batch 212 with 25 regions saved to Africa_all_2008_2024_regions_batch_212.json
# Batch 213 with 25 regions saved to Africa_all_2008_2024_regions_batch_213.json
# Batch 214 with 25 regions saved to Africa_all_2008_2024_regions_batch_214.json
# Batch 215 with 25 regions saved to Africa_all_2008_2024_regions_batch_215.json
# Batch 216 with 25 regions saved to Africa_all_2008_2024_regions_batch_216.json
# Batch 217 with 25 regions saved to Africa_all_2008_2024_regions_batch_217.json
# Batch 218 with 25 regions saved to Africa_all_2008_2024_regions_batch_218.json
# Batch 219 with 25 regions saved to Africa_all_2008_2024_regions_batch_219.json
# Batch 220 with 25 regions saved to Africa_all_2008_2024_regions_batch_220.json
# Batch 221 with 25 regions saved to Africa_all_2008_2024_regions_batch_221.json
# Batch 222 with 25 regions saved to Africa_all_2008_2024_regions_batch_222.json
# Batch 223 with 25 regions saved to Africa_all_2008_2024_regions_batch_223.json
# Batch 224 with 25 regions saved to Africa_all_2008_2024_regions_batch_224.json
# Batch 225 with 25 regions saved to Africa_all_2008_2024_regions_batch_225.json
# Batch 226 with 25 regions saved to Africa_all_2008_2024_regions_batch_226.json
# Batch 227 with 25 regions saved to Africa_all_2008_2024_regions_batch_227.json
# Batch 228 with 25 regions saved to Africa_all_2008_2024_regions_batch_228.json
# Batch 229 with 25 regions saved to Africa_all_2008_2024_regions_batch_229.json
# Batch 230 with 25 regions saved to Africa_all_2008_2024_regions_batch_230.json
# Batch 231 with 25 regions saved to Africa_all_2008_2024_regions_batch_231.json
# Batch 232 with 25 regions saved to Africa_all_2008_2024_regions_batch_232.json
# Batch 233 with 25 regions saved to Africa_all_2008_2024_regions_batch_233.json
# Batch 234 with 25 regions saved to Africa_all_2008_2024_regions_batch_234.json
# Batch 235 with 25 regions saved to Africa_all_2008_2024_regions_batch_235.json
# Batch 236 with 25 regions saved to Africa_all_2008_2024_regions_batch_236.json
# Batch 237 with 25 regions saved to Africa_all_2008_2024_regions_batch_237.json
# Batch 238 with 25 regions saved to Africa_all_2008_2024_regions_batch_238.json
# Batch 239 with 25 regions saved to Africa_all_2008_2024_regions_batch_239.json
# Batch 240 with 25 regions saved to Africa_all_2008_2024_regions_batch_240.json
# Batch 241 with 25 regions saved to Africa_all_2008_2024_regions_batch_241.json
# Batch 242 with 25 regions saved to Africa_all_2008_2024_regions_batch_242.json
# Batch 243 with 25 regions saved to Africa_all_2008_2024_regions_batch_243.json
# Batch 244 with 25 regions saved to Africa_all_2008_2024_regions_batch_244.json
# Batch 245 with 25 regions saved to Africa_all_2008_2024_regions_batch_245.json
# Batch 246 with 25 regions saved to Africa_all_2008_2024_regions_batch_246.json
# Batch 247 with 25 regions saved to Africa_all_2008_2024_regions_batch_247.json
# Batch 248 with 25 regions saved to Africa_all_2008_2024_regions_batch_248.json
# Batch 249 with 25 regions saved to Africa_all_2008_2024_regions_batch_249.json
# Batch 250 with 25 regions saved to Africa_all_2008_2024_regions_batch_250.json
# Batch 251 with 25 regions saved to Africa_all_2008_2024_regions_batch_251.json
# Batch 252 with 25 regions saved to Africa_all_2008_2024_regions_batch_252.json
# Batch 253 with 25 regions saved to Africa_all_2008_2024_regions_batch_253.json
# Batch 254 with 25 regions saved to Africa_all_2008_2024_regions_batch_254.json
# Batch 255 with 25 regions saved to Africa_all_2008_2024_regions_batch_255.json
# Batch 256 with 25 regions saved to Africa_all_2008_2024_regions_batch_256.json
# Batch 257 with 25 regions saved to Africa_all_2008_2024_regions_batch_257.json
# Batch 258 with 25 regions saved to Africa_all_2008_2024_regions_batch_258.json
# Batch 259 with 25 regions saved to Africa_all_2008_2024_regions_batch_259.json
# Batch 260 with 25 regions saved to Africa_all_2008_2024_regions_batch_260.json
# Batch 261 with 25 regions saved to Africa_all_2008_2024_regions_batch_261.json
# Batch 262 with 25 regions saved to Africa_all_2008_2024_regions_batch_262.json
# Batch 263 with 25 regions saved to Africa_all_2008_2024_regions_batch_263.json
# Batch 264 with 25 regions saved to Africa_all_2008_2024_regions_batch_264.json
# Batch 265 with 25 regions saved to Africa_all_2008_2024_regions_batch_265.json
# Batch 266 with 25 regions saved to Africa_all_2008_2024_regions_batch_266.json
# Batch 267 with 25 regions saved to Africa_all_2008_2024_regions_batch_267.json
# Batch 268 with 25 regions saved to Africa_all_2008_2024_regions_batch_268.json
# Batch 269 with 25 regions saved to Africa_all_2008_2024_regions_batch_269.json
# Batch 270 with 25 regions saved to Africa_all_2008_2024_regions_batch_270.json
# Batch 271 with 25 regions saved to Africa_all_2008_2024_regions_batch_271.json
# Batch 272 with 25 regions saved to Africa_all_2008_2024_regions_batch_272.json
# Batch 273 with 25 regions saved to Africa_all_2008_2024_regions_batch_273.json
# Batch 274 with 25 regions saved to Africa_all_2008_2024_regions_batch_274.json
# Batch 275 with 25 regions saved to Africa_all_2008_2024_regions_batch_275.json
# Batch 276 with 25 regions saved to Africa_all_2008_2024_regions_batch_276.json
# Batch 277 with 25 regions saved to Africa_all_2008_2024_regions_batch_277.json
# Batch 278 with 25 regions saved to Africa_all_2008_2024_regions_batch_278.json
# Batch 279 with 25 regions saved to Africa_all_2008_2024_regions_batch_279.json
# Batch 280 with 25 regions saved to Africa_all_2008_2024_regions_batch_280.json
# Batch 281 with 25 regions saved to Africa_all_2008_2024_regions_batch_281.json
# Batch 282 with 25 regions saved to Africa_all_2008_2024_regions_batch_282.json
# Batch 283 with 25 regions saved to Africa_all_2008_2024_regions_batch_283.json
# Batch 284 with 25 regions saved to Africa_all_2008_2024_regions_batch_284.json
# Batch 285 with 25 regions saved to Africa_all_2008_2024_regions_batch_285.json
# Batch 286 with 25 regions saved to Africa_all_2008_2024_regions_batch_286.json
# Batch 287 with 25 regions saved to Africa_all_2008_2024_regions_batch_287.json
# Batch 288 with 25 regions saved to Africa_all_2008_2024_regions_batch_288.json
# Batch 289 with 25 regions saved to Africa_all_2008_2024_regions_batch_289.json
# Batch 290 with 25 regions saved to Africa_all_2008_2024_regions_batch_290.json
# Batch 291 with 25 regions saved to Africa_all_2008_2024_regions_batch_291.json
# Batch 292 with 25 regions saved to Africa_all_2008_2024_regions_batch_292.json
# Batch 293 with 25 regions saved to Africa_all_2008_2024_regions_batch_293.json
# Batch 294 with 25 regions saved to Africa_all_2008_2024_regions_batch_294.json
# Batch 295 with 25 regions saved to Africa_all_2008_2024_regions_batch_295.json
# Batch 296 with 25 regions saved to Africa_all_2008_2024_regions_batch_296.json
# Batch 297 with 25 regions saved to Africa_all_2008_2024_regions_batch_297.json
# Batch 298 with 25 regions saved to Africa_all_2008_2024_regions_batch_298.json
# Batch 299 with 25 regions saved to Africa_all_2008_2024_regions_batch_299.json
# Batch 300 with 25 regions saved to Africa_all_2008_2024_regions_batch_300.json
# Batch 301 with 25 regions saved to Africa_all_2008_2024_regions_batch_301.json
# Batch 302 with 25 regions saved to Africa_all_2008_2024_regions_batch_302.json
# Batch 303 with 25 regions saved to Africa_all_2008_2024_regions_batch_303.json
# Batch 304 with 25 regions saved to Africa_all_2008_2024_regions_batch_304.json
# Batch 305 with 25 regions saved to Africa_all_2008_2024_regions_batch_305.json
# Batch 306 with 25 regions saved to Africa_all_2008_2024_regions_batch_306.json
# Batch 307 with 25 regions saved to Africa_all_2008_2024_regions_batch_307.json
# Batch 308 with 25 regions saved to Africa_all_2008_2024_regions_batch_308.json
# Batch 309 with 25 regions saved to Africa_all_2008_2024_regions_batch_309.json
# Batch 310 with 25 regions saved to Africa_all_2008_2024_regions_batch_310.json
# Batch 311 with 25 regions saved to Africa_all_2008_2024_regions_batch_311.json
# Batch 312 with 25 regions saved to Africa_all_2008_2024_regions_batch_312.json
# Batch 313 with 25 regions saved to Africa_all_2008_2024_regions_batch_313.json
# Batch 314 with 25 regions saved to Africa_all_2008_2024_regions_batch_314.json
# Batch 315 with 25 regions saved to Africa_all_2008_2024_regions_batch_315.json
# Batch 316 with 25 regions saved to Africa_all_2008_2024_regions_batch_316.json
# Batch 317 with 25 regions saved to Africa_all_2008_2024_regions_batch_317.json
# Batch 318 with 25 regions saved to Africa_all_2008_2024_regions_batch_318.json
# Batch 319 with 25 regions saved to Africa_all_2008_2024_regions_batch_319.json
# Batch 320 with 25 regions saved to Africa_all_2008_2024_regions_batch_320.json
# Batch 321 with 25 regions saved to Africa_all_2008_2024_regions_batch_321.json
# Batch 322 with 25 regions saved to Africa_all_2008_2024_regions_batch_322.json
# Batch 323 with 25 regions saved to Africa_all_2008_2024_regions_batch_323.json
# Batch 324 with 25 regions saved to Africa_all_2008_2024_regions_batch_324.json
# Batch 325 with 25 regions saved to Africa_all_2008_2024_regions_batch_325.json
# Batch 326 with 25 regions saved to Africa_all_2008_2024_regions_batch_326.json
# Batch 327 with 25 regions saved to Africa_all_2008_2024_regions_batch_327.json
# Batch 328 with 25 regions saved to Africa_all_2008_2024_regions_batch_328.json
# Batch 329 with 25 regions saved to Africa_all_2008_2024_regions_batch_329.json
# Batch 330 with 25 regions saved to Africa_all_2008_2024_regions_batch_330.json
# Batch 331 with 25 regions saved to Africa_all_2008_2024_regions_batch_331.json
# Batch 332 with 25 regions saved to Africa_all_2008_2024_regions_batch_332.json
# Batch 333 with 25 regions saved to Africa_all_2008_2024_regions_batch_333.json
# Batch 334 with 25 regions saved to Africa_all_2008_2024_regions_batch_334.json
# Batch 335 with 25 regions saved to Africa_all_2008_2024_regions_batch_335.json
# Batch 336 with 25 regions saved to Africa_all_2008_2024_regions_batch_336.json
# Batch 337 with 25 regions saved to Africa_all_2008_2024_regions_batch_337.json
# Batch 338 with 25 regions saved to Africa_all_2008_2024_regions_batch_338.json
# Batch 339 with 25 regions saved to Africa_all_2008_2024_regions_batch_339.json
# Batch 340 with 25 regions saved to Africa_all_2008_2024_regions_batch_340.json
# Batch 341 with 25 regions saved to Africa_all_2008_2024_regions_batch_341.json
# Batch 342 with 25 regions saved to Africa_all_2008_2024_regions_batch_342.json
# Batch 343 with 25 regions saved to Africa_all_2008_2024_regions_batch_343.json
# Batch 344 with 25 regions saved to Africa_all_2008_2024_regions_batch_344.json
# Batch 345 with 25 regions saved to Africa_all_2008_2024_regions_batch_345.json
# Batch 346 with 25 regions saved to Africa_all_2008_2024_regions_batch_346.json
# Batch 347 with 25 regions saved to Africa_all_2008_2024_regions_batch_347.json
# Batch 348 with 25 regions saved to Africa_all_2008_2024_regions_batch_348.json
# Batch 349 with 25 regions saved to Africa_all_2008_2024_regions_batch_349.json
# Batch 350 with 25 regions saved to Africa_all_2008_2024_regions_batch_350.json
# Batch 351 with 25 regions saved to Africa_all_2008_2024_regions_batch_351.json
# Batch 352 with 25 regions saved to Africa_all_2008_2024_regions_batch_352.json
# Batch 353 with 25 regions saved to Africa_all_2008_2024_regions_batch_353.json
# Batch 354 with 25 regions saved to Africa_all_2008_2024_regions_batch_354.json
# Batch 355 with 25 regions saved to Africa_all_2008_2024_regions_batch_355.json
# Batch 356 with 25 regions saved to Africa_all_2008_2024_regions_batch_356.json
# Batch 357 with 25 regions saved to Africa_all_2008_2024_regions_batch_357.json
# Batch 358 with 25 regions saved to Africa_all_2008_2024_regions_batch_358.json
# Batch 359 with 25 regions saved to Africa_all_2008_2024_regions_batch_359.json
# Batch 360 with 25 regions saved to Africa_all_2008_2024_regions_batch_360.json
# Batch 361 with 25 regions saved to Africa_all_2008_2024_regions_batch_361.json
# Batch 362 with 25 regions saved to Africa_all_2008_2024_regions_batch_362.json
# Batch 363 with 25 regions saved to Africa_all_2008_2024_regions_batch_363.json
# Batch 364 with 25 regions saved to Africa_all_2008_2024_regions_batch_364.json
# Batch 365 with 25 regions saved to Africa_all_2008_2024_regions_batch_365.json
# Batch 366 with 25 regions saved to Africa_all_2008_2024_regions_batch_366.json
# Batch 367 with 25 regions saved to Africa_all_2008_2024_regions_batch_367.json
# Batch 368 with 25 regions saved to Africa_all_2008_2024_regions_batch_368.json
# Batch 369 with 25 regions saved to Africa_all_2008_2024_regions_batch_369.json
# Batch 370 with 25 regions saved to Africa_all_2008_2024_regions_batch_370.json
# Batch 371 with 25 regions saved to Africa_all_2008_2024_regions_batch_371.json
# Batch 372 with 25 regions saved to Africa_all_2008_2024_regions_batch_372.json
# Batch 373 with 25 regions saved to Africa_all_2008_2024_regions_batch_373.json
# Batch 374 with 25 regions saved to Africa_all_2008_2024_regions_batch_374.json
# Batch 375 with 25 regions saved to Africa_all_2008_2024_regions_batch_375.json
# Batch 376 with 25 regions saved to Africa_all_2008_2024_regions_batch_376.json
# Batch 377 with 25 regions saved to Africa_all_2008_2024_regions_batch_377.json
# Batch 378 with 25 regions saved to Africa_all_2008_2024_regions_batch_378.json
# Batch 379 with 25 regions saved to Africa_all_2008_2024_regions_batch_379.json
# Batch 380 with 25 regions saved to Africa_all_2008_2024_regions_batch_380.json
# Batch 381 with 25 regions saved to Africa_all_2008_2024_regions_batch_381.json
# Batch 382 with 25 regions saved to Africa_all_2008_2024_regions_batch_382.json
# Batch 383 with 25 regions saved to Africa_all_2008_2024_regions_batch_383.json
# Batch 384 with 25 regions saved to Africa_all_2008_2024_regions_batch_384.json
# Batch 385 with 25 regions saved to Africa_all_2008_2024_regions_batch_385.json
# Batch 386 with 25 regions saved to Africa_all_2008_2024_regions_batch_386.json
# Batch 387 with 25 regions saved to Africa_all_2008_2024_regions_batch_387.json
# Batch 388 with 25 regions saved to Africa_all_2008_2024_regions_batch_388.json
# Batch 389 with 25 regions saved to Africa_all_2008_2024_regions_batch_389.json
# Batch 390 with 25 regions saved to Africa_all_2008_2024_regions_batch_390.json
# Batch 391 with 25 regions saved to Africa_all_2008_2024_regions_batch_391.json
# Batch 392 with 25 regions saved to Africa_all_2008_2024_regions_batch_392.json
# Batch 393 with 25 regions saved to Africa_all_2008_2024_regions_batch_393.json
# Batch 394 with 25 regions saved to Africa_all_2008_2024_regions_batch_394.json
# Batch 395 with 25 regions saved to Africa_all_2008_2024_regions_batch_395.json
# Batch 396 with 25 regions saved to Africa_all_2008_2024_regions_batch_396.json
# Batch 397 with 25 regions saved to Africa_all_2008_2024_regions_batch_397.json
# Batch 398 with 25 regions saved to Africa_all_2008_2024_regions_batch_398.json
# Batch 399 with 25 regions saved to Africa_all_2008_2024_regions_batch_399.json
# Batch 400 with 25 regions saved to Africa_all_2008_2024_regions_batch_400.json
# Batch 401 with 25 regions saved to Africa_all_2008_2024_regions_batch_401.json
# Batch 402 with 25 regions saved to Africa_all_2008_2024_regions_batch_402.json
# Batch 403 with 25 regions saved to Africa_all_2008_2024_regions_batch_403.json
# Batch 404 with 25 regions saved to Africa_all_2008_2024_regions_batch_404.json
# Batch 405 with 25 regions saved to Africa_all_2008_2024_regions_batch_405.json
# Batch 406 with 25 regions saved to Africa_all_2008_2024_regions_batch_406.json
# Batch 407 with 25 regions saved to Africa_all_2008_2024_regions_batch_407.json
# Batch 408 with 25 regions saved to Africa_all_2008_2024_regions_batch_408.json
# Batch 409 with 25 regions saved to Africa_all_2008_2024_regions_batch_409.json
# Batch 410 with 25 regions saved to Africa_all_2008_2024_regions_batch_410.json
# Batch 411 with 25 regions saved to Africa_all_2008_2024_regions_batch_411.json
# Batch 412 with 25 regions saved to Africa_all_2008_2024_regions_batch_412.json
# Batch 413 with 25 regions saved to Africa_all_2008_2024_regions_batch_413.json
# Batch 414 with 25 regions saved to Africa_all_2008_2024_regions_batch_414.json
# Batch 415 with 25 regions saved to Africa_all_2008_2024_regions_batch_415.json
# Batch 416 with 25 regions saved to Africa_all_2008_2024_regions_batch_416.json
# Batch 417 with 25 regions saved to Africa_all_2008_2024_regions_batch_417.json
# Batch 418 with 25 regions saved to Africa_all_2008_2024_regions_batch_418.json
# Batch 419 with 25 regions saved to Africa_all_2008_2024_regions_batch_419.json
# Batch 420 with 25 regions saved to Africa_all_2008_2024_regions_batch_420.json
# Batch 421 with 25 regions saved to Africa_all_2008_2024_regions_batch_421.json
# Batch 422 with 25 regions saved to Africa_all_2008_2024_regions_batch_422.json
# Batch 423 with 25 regions saved to Africa_all_2008_2024_regions_batch_423.json
# Batch 424 with 25 regions saved to Africa_all_2008_2024_regions_batch_424.json
# Batch 425 with 25 regions saved to Africa_all_2008_2024_regions_batch_425.json
# Batch 426 with 25 regions saved to Africa_all_2008_2024_regions_batch_426.json
# Batch 427 with 25 regions saved to Africa_all_2008_2024_regions_batch_427.json
# Batch 428 with 25 regions saved to Africa_all_2008_2024_regions_batch_428.json
# Batch 429 with 25 regions saved to Africa_all_2008_2024_regions_batch_429.json
# Batch 430 with 25 regions saved to Africa_all_2008_2024_regions_batch_430.json
# Batch 431 with 25 regions saved to Africa_all_2008_2024_regions_batch_431.json
# Batch 432 with 25 regions saved to Africa_all_2008_2024_regions_batch_432.json
# Batch 433 with 25 regions saved to Africa_all_2008_2024_regions_batch_433.json
# Batch 434 with 25 regions saved to Africa_all_2008_2024_regions_batch_434.json
# Batch 435 with 25 regions saved to Africa_all_2008_2024_regions_batch_435.json
# Batch 436 with 25 regions saved to Africa_all_2008_2024_regions_batch_436.json
# Batch 437 with 25 regions saved to Africa_all_2008_2024_regions_batch_437.json
# Batch 438 with 25 regions saved to Africa_all_2008_2024_regions_batch_438.json
# Batch 439 with 25 regions saved to Africa_all_2008_2024_regions_batch_439.json
# Batch 440 with 25 regions saved to Africa_all_2008_2024_regions_batch_440.json
# Batch 441 with 25 regions saved to Africa_all_2008_2024_regions_batch_441.json
# Batch 442 with 25 regions saved to Africa_all_2008_2024_regions_batch_442.json
# Batch 443 with 25 regions saved to Africa_all_2008_2024_regions_batch_443.json
# Batch 444 with 25 regions saved to Africa_all_2008_2024_regions_batch_444.json
# Batch 445 with 25 regions saved to Africa_all_2008_2024_regions_batch_445.json
# Batch 446 with 25 regions saved to Africa_all_2008_2024_regions_batch_446.json
# Batch 447 with 25 regions saved to Africa_all_2008_2024_regions_batch_447.json
# Batch 448 with 25 regions saved to Africa_all_2008_2024_regions_batch_448.json
# Batch 449 with 25 regions saved to Africa_all_2008_2024_regions_batch_449.json
# Batch 450 with 25 regions saved to Africa_all_2008_2024_regions_batch_450.json
# Batch 451 with 25 regions saved to Africa_all_2008_2024_regions_batch_451.json
# Batch 452 with 25 regions saved to Africa_all_2008_2024_regions_batch_452.json
# Batch 453 with 25 regions saved to Africa_all_2008_2024_regions_batch_453.json
# Batch 454 with 25 regions saved to Africa_all_2008_2024_regions_batch_454.json
# Batch 455 with 25 regions saved to Africa_all_2008_2024_regions_batch_455.json
# Batch 456 with 25 regions saved to Africa_all_2008_2024_regions_batch_456.json
# Batch 457 with 25 regions saved to Africa_all_2008_2024_regions_batch_457.json
# Batch 458 with 25 regions saved to Africa_all_2008_2024_regions_batch_458.json
# Batch 459 with 25 regions saved to Africa_all_2008_2024_regions_batch_459.json
# Batch 460 with 25 regions saved to Africa_all_2008_2024_regions_batch_460.json
# Batch 461 with 25 regions saved to Africa_all_2008_2024_regions_batch_461.json
# Batch 462 with 25 regions saved to Africa_all_2008_2024_regions_batch_462.json
# Batch 463 with 25 regions saved to Africa_all_2008_2024_regions_batch_463.json
# Batch 464 with 25 regions saved to Africa_all_2008_2024_regions_batch_464.json
# Batch 465 with 25 regions saved to Africa_all_2008_2024_regions_batch_465.json
# Batch 466 with 25 regions saved to Africa_all_2008_2024_regions_batch_466.json
# Batch 467 with 25 regions saved to Africa_all_2008_2024_regions_batch_467.json
# Batch 468 with 25 regions saved to Africa_all_2008_2024_regions_batch_468.json
# Batch 469 with 25 regions saved to Africa_all_2008_2024_regions_batch_469.json
# Batch 470 with 25 regions saved to Africa_all_2008_2024_regions_batch_470.json
# Batch 471 with 25 regions saved to Africa_all_2008_2024_regions_batch_471.json
# Batch 472 with 25 regions saved to Africa_all_2008_2024_regions_batch_472.json
# Batch 473 with 25 regions saved to Africa_all_2008_2024_regions_batch_473.json
# Batch 474 with 25 regions saved to Africa_all_2008_2024_regions_batch_474.json
# Batch 475 with 25 regions saved to Africa_all_2008_2024_regions_batch_475.json
# Batch 476 with 25 regions saved to Africa_all_2008_2024_regions_batch_476.json
# Batch 477 with 25 regions saved to Africa_all_2008_2024_regions_batch_477.json
# Batch 478 with 25 regions saved to Africa_all_2008_2024_regions_batch_478.json
# Batch 479 with 25 regions saved to Africa_all_2008_2024_regions_batch_479.json
# Batch 480 with 25 regions saved to Africa_all_2008_2024_regions_batch_480.json
# Batch 481 with 25 regions saved to Africa_all_2008_2024_regions_batch_481.json
# Batch 482 with 25 regions saved to Africa_all_2008_2024_regions_batch_482.json
# Batch 483 with 25 regions saved to Africa_all_2008_2024_regions_batch_483.json
# Batch 484 with 25 regions saved to Africa_all_2008_2024_regions_batch_484.json
# Batch 485 with 25 regions saved to Africa_all_2008_2024_regions_batch_485.json
# Batch 486 with 25 regions saved to Africa_all_2008_2024_regions_batch_486.json
# Batch 487 with 25 regions saved to Africa_all_2008_2024_regions_batch_487.json
# Batch 488 with 25 regions saved to Africa_all_2008_2024_regions_batch_488.json
# Batch 489 with 25 regions saved to Africa_all_2008_2024_regions_batch_489.json
# Batch 490 with 25 regions saved to Africa_all_2008_2024_regions_batch_490.json
# Batch 491 with 25 regions saved to Africa_all_2008_2024_regions_batch_491.json
# Batch 492 with 25 regions saved to Africa_all_2008_2024_regions_batch_492.json
# Batch 493 with 25 regions saved to Africa_all_2008_2024_regions_batch_493.json
# Batch 494 with 25 regions saved to Africa_all_2008_2024_regions_batch_494.json
# Batch 495 with 25 regions saved to Africa_all_2008_2024_regions_batch_495.json
# Batch 496 with 25 regions saved to Africa_all_2008_2024_regions_batch_496.json
# Batch 497 with 25 regions saved to Africa_all_2008_2024_regions_batch_497.json
# Batch 498 with 25 regions saved to Africa_all_2008_2024_regions_batch_498.json
# Batch 499 with 25 regions saved to Africa_all_2008_2024_regions_batch_499.json
# Batch 500 with 25 regions saved to Africa_all_2008_2024_regions_batch_500.json
# Batch 501 with 25 regions saved to Africa_all_2008_2024_regions_batch_501.json
# Batch 502 with 25 regions saved to Africa_all_2008_2024_regions_batch_502.json
# Batch 503 with 25 regions saved to Africa_all_2008_2024_regions_batch_503.json
# Batch 504 with 25 regions saved to Africa_all_2008_2024_regions_batch_504.json
# Batch 505 with 25 regions saved to Africa_all_2008_2024_regions_batch_505.json
# Batch 506 with 25 regions saved to Africa_all_2008_2024_regions_batch_506.json
# Batch 507 with 25 regions saved to Africa_all_2008_2024_regions_batch_507.json
# Batch 508 with 25 regions saved to Africa_all_2008_2024_regions_batch_508.json
# Batch 509 with 25 regions saved to Africa_all_2008_2024_regions_batch_509.json
# Batch 510 with 25 regions saved to Africa_all_2008_2024_regions_batch_510.json
# Batch 511 with 25 regions saved to Africa_all_2008_2024_regions_batch_511.json
# Batch 512 with 25 regions saved to Africa_all_2008_2024_regions_batch_512.json
# Batch 513 with 25 regions saved to Africa_all_2008_2024_regions_batch_513.json
# Batch 514 with 25 regions saved to Africa_all_2008_2024_regions_batch_514.json
# Batch 515 with 25 regions saved to Africa_all_2008_2024_regions_batch_515.json
# Batch 516 with 25 regions saved to Africa_all_2008_2024_regions_batch_516.json
# Batch 517 with 25 regions saved to Africa_all_2008_2024_regions_batch_517.json
# Batch 518 with 25 regions saved to Africa_all_2008_2024_regions_batch_518.json
# Batch 519 with 25 regions saved to Africa_all_2008_2024_regions_batch_519.json
# Batch 520 with 25 regions saved to Africa_all_2008_2024_regions_batch_520.json
# Batch 521 with 25 regions saved to Africa_all_2008_2024_regions_batch_521.json
# Batch 522 with 25 regions saved to Africa_all_2008_2024_regions_batch_522.json
# Batch 523 with 25 regions saved to Africa_all_2008_2024_regions_batch_523.json
# Batch 524 with 25 regions saved to Africa_all_2008_2024_regions_batch_524.json
# Batch 525 with 25 regions saved to Africa_all_2008_2024_regions_batch_525.json
# Batch 526 with 25 regions saved to Africa_all_2008_2024_regions_batch_526.json
# Batch 527 with 25 regions saved to Africa_all_2008_2024_regions_batch_527.json
# Batch 528 with 25 regions saved to Africa_all_2008_2024_regions_batch_528.json
# Batch 529 with 25 regions saved to Africa_all_2008_2024_regions_batch_529.json
# Batch 530 with 25 regions saved to Africa_all_2008_2024_regions_batch_530.json
# Batch 531 with 25 regions saved to Africa_all_2008_2024_regions_batch_531.json
# Batch 532 with 25 regions saved to Africa_all_2008_2024_regions_batch_532.json
# Batch 533 with 25 regions saved to Africa_all_2008_2024_regions_batch_533.json
# Batch 534 with 25 regions saved to Africa_all_2008_2024_regions_batch_534.json
# Batch 535 with 25 regions saved to Africa_all_2008_2024_regions_batch_535.json
# Batch 536 with 25 regions saved to Africa_all_2008_2024_regions_batch_536.json
# Batch 537 with 25 regions saved to Africa_all_2008_2024_regions_batch_537.json
# Batch 538 with 25 regions saved to Africa_all_2008_2024_regions_batch_538.json
# Batch 539 with 25 regions saved to Africa_all_2008_2024_regions_batch_539.json
# Batch 540 with 25 regions saved to Africa_all_2008_2024_regions_batch_540.json
# Batch 541 with 25 regions saved to Africa_all_2008_2024_regions_batch_541.json
# Batch 542 with 25 regions saved to Africa_all_2008_2024_regions_batch_542.json
# Batch 543 with 25 regions saved to Africa_all_2008_2024_regions_batch_543.json
# Batch 544 with 25 regions saved to Africa_all_2008_2024_regions_batch_544.json
# Batch 545 with 25 regions saved to Africa_all_2008_2024_regions_batch_545.json
# Batch 546 with 25 regions saved to Africa_all_2008_2024_regions_batch_546.json
# Batch 547 with 25 regions saved to Africa_all_2008_2024_regions_batch_547.json
# Batch 548 with 25 regions saved to Africa_all_2008_2024_regions_batch_548.json
# Batch 549 with 25 regions saved to Africa_all_2008_2024_regions_batch_549.json
# Batch 550 with 25 regions saved to Africa_all_2008_2024_regions_batch_550.json
# Batch 551 with 25 regions saved to Africa_all_2008_2024_regions_batch_551.json
# Batch 552 with 25 regions saved to Africa_all_2008_2024_regions_batch_552.json
# Batch 553 with 25 regions saved to Africa_all_2008_2024_regions_batch_553.json
# Batch 554 with 25 regions saved to Africa_all_2008_2024_regions_batch_554.json
# Batch 555 with 25 regions saved to Africa_all_2008_2024_regions_batch_555.json
# Batch 556 with 25 regions saved to Africa_all_2008_2024_regions_batch_556.json
# Batch 557 with 25 regions saved to Africa_all_2008_2024_regions_batch_557.json
# Batch 558 with 25 regions saved to Africa_all_2008_2024_regions_batch_558.json
# Batch 559 with 25 regions saved to Africa_all_2008_2024_regions_batch_559.json
# Batch 560 with 25 regions saved to Africa_all_2008_2024_regions_batch_560.json
# Batch 561 with 25 regions saved to Africa_all_2008_2024_regions_batch_561.json
# Batch 562 with 25 regions saved to Africa_all_2008_2024_regions_batch_562.json
# Batch 563 with 25 regions saved to Africa_all_2008_2024_regions_batch_563.json
# Batch 564 with 25 regions saved to Africa_all_2008_2024_regions_batch_564.json
# Batch 565 with 25 regions saved to Africa_all_2008_2024_regions_batch_565.json
# Batch 566 with 25 regions saved to Africa_all_2008_2024_regions_batch_566.json
# Batch 567 with 25 regions saved to Africa_all_2008_2024_regions_batch_567.json
# Batch 568 with 25 regions saved to Africa_all_2008_2024_regions_batch_568.json
# Batch 569 with 25 regions saved to Africa_all_2008_2024_regions_batch_569.json
# Batch 570 with 25 regions saved to Africa_all_2008_2024_regions_batch_570.json
# Batch 571 with 25 regions saved to Africa_all_2008_2024_regions_batch_571.json
# Batch 572 with 25 regions saved to Africa_all_2008_2024_regions_batch_572.json
# Batch 573 with 25 regions saved to Africa_all_2008_2024_regions_batch_573.json
# Batch 574 with 25 regions saved to Africa_all_2008_2024_regions_batch_574.json
# Batch 575 with 25 regions saved to Africa_all_2008_2024_regions_batch_575.json
# Batch 576 with 25 regions saved to Africa_all_2008_2024_regions_batch_576.json
# Batch 577 with 25 regions saved to Africa_all_2008_2024_regions_batch_577.json
# Batch 578 with 25 regions saved to Africa_all_2008_2024_regions_batch_578.json
# Batch 579 with 25 regions saved to Africa_all_2008_2024_regions_batch_579.json
# Batch 580 with 25 regions saved to Africa_all_2008_2024_regions_batch_580.json
# Batch 581 with 25 regions saved to Africa_all_2008_2024_regions_batch_581.json
# Batch 582 with 25 regions saved to Africa_all_2008_2024_regions_batch_582.json
# Batch 583 with 25 regions saved to Africa_all_2008_2024_regions_batch_583.json
# Batch 584 with 25 regions saved to Africa_all_2008_2024_regions_batch_584.json
# Batch 585 with 25 regions saved to Africa_all_2008_2024_regions_batch_585.json
# Batch 586 with 25 regions saved to Africa_all_2008_2024_regions_batch_586.json
# Batch 587 with 25 regions saved to Africa_all_2008_2024_regions_batch_587.json
# Batch 588 with 25 regions saved to Africa_all_2008_2024_regions_batch_588.json
# Batch 589 with 25 regions saved to Africa_all_2008_2024_regions_batch_589.json
# Batch 590 with 25 regions saved to Africa_all_2008_2024_regions_batch_590.json
# Batch 591 with 25 regions saved to Africa_all_2008_2024_regions_batch_591.json
# Batch 592 with 25 regions saved to Africa_all_2008_2024_regions_batch_592.json
# Batch 593 with 25 regions saved to Africa_all_2008_2024_regions_batch_593.json
# Batch 594 with 25 regions saved to Africa_all_2008_2024_regions_batch_594.json
# Batch 595 with 25 regions saved to Africa_all_2008_2024_regions_batch_595.json
# Batch 596 with 25 regions saved to Africa_all_2008_2024_regions_batch_596.json
# Batch 597 with 25 regions saved to Africa_all_2008_2024_regions_batch_597.json
# Batch 598 with 25 regions saved to Africa_all_2008_2024_regions_batch_598.json
# Batch 599 with 25 regions saved to Africa_all_2008_2024_regions_batch_599.json
# Batch 600 with 25 regions saved to Africa_all_2008_2024_regions_batch_600.json
# Batch 601 with 25 regions saved to Africa_all_2008_2024_regions_batch_601.json
# Batch 602 with 25 regions saved to Africa_all_2008_2024_regions_batch_602.json
# Batch 603 with 25 regions saved to Africa_all_2008_2024_regions_batch_603.json
# Batch 604 with 25 regions saved to Africa_all_2008_2024_regions_batch_604.json
# Batch 605 with 25 regions saved to Africa_all_2008_2024_regions_batch_605.json
# Batch 606 with 25 regions saved to Africa_all_2008_2024_regions_batch_606.json
# Batch 607 with 25 regions saved to Africa_all_2008_2024_regions_batch_607.json
# Batch 608 with 25 regions saved to Africa_all_2008_2024_regions_batch_608.json
# Batch 609 with 25 regions saved to Africa_all_2008_2024_regions_batch_609.json
# Batch 610 with 25 regions saved to Africa_all_2008_2024_regions_batch_610.json
# Batch 611 with 25 regions saved to Africa_all_2008_2024_regions_batch_611.json
# Batch 612 with 25 regions saved to Africa_all_2008_2024_regions_batch_612.json
# Batch 613 with 25 regions saved to Africa_all_2008_2024_regions_batch_613.json
# Batch 614 with 25 regions saved to Africa_all_2008_2024_regions_batch_614.json
# Batch 615 with 25 regions saved to Africa_all_2008_2024_regions_batch_615.json
# Batch 616 with 25 regions saved to Africa_all_2008_2024_regions_batch_616.json
# Batch 617 with 25 regions saved to Africa_all_2008_2024_regions_batch_617.json
# Batch 618 with 25 regions saved to Africa_all_2008_2024_regions_batch_618.json
# Batch 619 with 25 regions saved to Africa_all_2008_2024_regions_batch_619.json
# Batch 620 with 25 regions saved to Africa_all_2008_2024_regions_batch_620.json
# Batch 621 with 25 regions saved to Africa_all_2008_2024_regions_batch_621.json
# Batch 622 with 25 regions saved to Africa_all_2008_2024_regions_batch_622.json
# Batch 623 with 25 regions saved to Africa_all_2008_2024_regions_batch_623.json
# Batch 624 with 25 regions saved to Africa_all_2008_2024_regions_batch_624.json
# Batch 625 with 25 regions saved to Africa_all_2008_2024_regions_batch_625.json
# Batch 626 with 25 regions saved to Africa_all_2008_2024_regions_batch_626.json
# Batch 627 with 25 regions saved to Africa_all_2008_2024_regions_batch_627.json
# Batch 628 with 25 regions saved to Africa_all_2008_2024_regions_batch_628.json
# Batch 629 with 25 regions saved to Africa_all_2008_2024_regions_batch_629.json
# Batch 630 with 25 regions saved to Africa_all_2008_2024_regions_batch_630.json
# Batch 631 with 25 regions saved to Africa_all_2008_2024_regions_batch_631.json
# Batch 632 with 25 regions saved to Africa_all_2008_2024_regions_batch_632.json
# Batch 633 with 25 regions saved to Africa_all_2008_2024_regions_batch_633.json
# Batch 634 with 25 regions saved to Africa_all_2008_2024_regions_batch_634.json
# Batch 635 with 25 regions saved to Africa_all_2008_2024_regions_batch_635.json
# Batch 636 with 25 regions saved to Africa_all_2008_2024_regions_batch_636.json
# Batch 637 with 25 regions saved to Africa_all_2008_2024_regions_batch_637.json
# Batch 638 with 25 regions saved to Africa_all_2008_2024_regions_batch_638.json
# Batch 639 with 25 regions saved to Africa_all_2008_2024_regions_batch_639.json
# Batch 640 with 25 regions saved to Africa_all_2008_2024_regions_batch_640.json
# Batch 641 with 25 regions saved to Africa_all_2008_2024_regions_batch_641.json
# Batch 642 with 25 regions saved to Africa_all_2008_2024_regions_batch_642.json
# Batch 643 with 25 regions saved to Africa_all_2008_2024_regions_batch_643.json
# Batch 644 with 25 regions saved to Africa_all_2008_2024_regions_batch_644.json
# Batch 645 with 25 regions saved to Africa_all_2008_2024_regions_batch_645.json
# Batch 646 with 25 regions saved to Africa_all_2008_2024_regions_batch_646.json
# Batch 647 with 25 regions saved to Africa_all_2008_2024_regions_batch_647.json
# Batch 648 with 25 regions saved to Africa_all_2008_2024_regions_batch_648.json
# Batch 649 with 25 regions saved to Africa_all_2008_2024_regions_batch_649.json
# Batch 650 with 25 regions saved to Africa_all_2008_2024_regions_batch_650.json
# Batch 651 with 25 regions saved to Africa_all_2008_2024_regions_batch_651.json
# Batch 652 with 25 regions saved to Africa_all_2008_2024_regions_batch_652.json
# Batch 653 with 25 regions saved to Africa_all_2008_2024_regions_batch_653.json
# Batch 654 with 25 regions saved to Africa_all_2008_2024_regions_batch_654.json
# Batch 655 with 25 regions saved to Africa_all_2008_2024_regions_batch_655.json
# Batch 656 with 25 regions saved to Africa_all_2008_2024_regions_batch_656.json
# Batch 657 with 25 regions saved to Africa_all_2008_2024_regions_batch_657.json
# Batch 658 with 25 regions saved to Africa_all_2008_2024_regions_batch_658.json
# Batch 659 with 25 regions saved to Africa_all_2008_2024_regions_batch_659.json
# Batch 660 with 25 regions saved to Africa_all_2008_2024_regions_batch_660.json
# Batch 661 with 25 regions saved to Africa_all_2008_2024_regions_batch_661.json
# Batch 662 with 25 regions saved to Africa_all_2008_2024_regions_batch_662.json
# Batch 663 with 25 regions saved to Africa_all_2008_2024_regions_batch_663.json
# Batch 664 with 25 regions saved to Africa_all_2008_2024_regions_batch_664.json
# Batch 665 with 25 regions saved to Africa_all_2008_2024_regions_batch_665.json
# Batch 666 with 25 regions saved to Africa_all_2008_2024_regions_batch_666.json
# Batch 667 with 25 regions saved to Africa_all_2008_2024_regions_batch_667.json
# Batch 668 with 25 regions saved to Africa_all_2008_2024_regions_batch_668.json
# Batch 669 with 25 regions saved to Africa_all_2008_2024_regions_batch_669.json
# Batch 670 with 25 regions saved to Africa_all_2008_2024_regions_batch_670.json
# Batch 671 with 25 regions saved to Africa_all_2008_2024_regions_batch_671.json
# Batch 672 with 25 regions saved to Africa_all_2008_2024_regions_batch_672.json
# Batch 673 with 25 regions saved to Africa_all_2008_2024_regions_batch_673.json
# Batch 674 with 25 regions saved to Africa_all_2008_2024_regions_batch_674.json
# Batch 675 with 25 regions saved to Africa_all_2008_2024_regions_batch_675.json
# Batch 676 with 25 regions saved to Africa_all_2008_2024_regions_batch_676.json
# Batch 677 with 25 regions saved to Africa_all_2008_2024_regions_batch_677.json
# Batch 678 with 25 regions saved to Africa_all_2008_2024_regions_batch_678.json
# Batch 679 with 25 regions saved to Africa_all_2008_2024_regions_batch_679.json
# Batch 680 with 25 regions saved to Africa_all_2008_2024_regions_batch_680.json
# Batch 681 with 25 regions saved to Africa_all_2008_2024_regions_batch_681.json
# Batch 682 with 25 regions saved to Africa_all_2008_2024_regions_batch_682.json
# Batch 683 with 25 regions saved to Africa_all_2008_2024_regions_batch_683.json
# Batch 684 with 25 regions saved to Africa_all_2008_2024_regions_batch_684.json
# Batch 685 with 25 regions saved to Africa_all_2008_2024_regions_batch_685.json
# Batch 686 with 25 regions saved to Africa_all_2008_2024_regions_batch_686.json
# Batch 687 with 25 regions saved to Africa_all_2008_2024_regions_batch_687.json
# Batch 688 with 25 regions saved to Africa_all_2008_2024_regions_batch_688.json
# Batch 689 with 25 regions saved to Africa_all_2008_2024_regions_batch_689.json
# Batch 690 with 25 regions saved to Africa_all_2008_2024_regions_batch_690.json
# Batch 691 with 25 regions saved to Africa_all_2008_2024_regions_batch_691.json
# Batch 692 with 25 regions saved to Africa_all_2008_2024_regions_batch_692.json
# Batch 693 with 25 regions saved to Africa_all_2008_2024_regions_batch_693.json
# Batch 694 with 25 regions saved to Africa_all_2008_2024_regions_batch_694.json
# Batch 695 with 25 regions saved to Africa_all_2008_2024_regions_batch_695.json
# Batch 696 with 25 regions saved to Africa_all_2008_2024_regions_batch_696.json
# Batch 697 with 25 regions saved to Africa_all_2008_2024_regions_batch_697.json
# Batch 698 with 25 regions saved to Africa_all_2008_2024_regions_batch_698.json
# Batch 699 with 25 regions saved to Africa_all_2008_2024_regions_batch_699.json
# Batch 700 with 25 regions saved to Africa_all_2008_2024_regions_batch_700.json
# Batch 701 with 25 regions saved to Africa_all_2008_2024_regions_batch_701.json
# Batch 702 with 25 regions saved to Africa_all_2008_2024_regions_batch_702.json
# Batch 703 with 25 regions saved to Africa_all_2008_2024_regions_batch_703.json
# Batch 704 with 25 regions saved to Africa_all_2008_2024_regions_batch_704.json
# Batch 705 with 25 regions saved to Africa_all_2008_2024_regions_batch_705.json
# Batch 706 with 25 regions saved to Africa_all_2008_2024_regions_batch_706.json
# Batch 707 with 25 regions saved to Africa_all_2008_2024_regions_batch_707.json
# Batch 708 with 25 regions saved to Africa_all_2008_2024_regions_batch_708.json
# Batch 709 with 25 regions saved to Africa_all_2008_2024_regions_batch_709.json
# Batch 710 with 25 regions saved to Africa_all_2008_2024_regions_batch_710.json
# Batch 711 with 25 regions saved to Africa_all_2008_2024_regions_batch_711.json
# Batch 712 with 25 regions saved to Africa_all_2008_2024_regions_batch_712.json
# Batch 713 with 25 regions saved to Africa_all_2008_2024_regions_batch_713.json
# Batch 714 with 25 regions saved to Africa_all_2008_2024_regions_batch_714.json
# Batch 715 with 25 regions saved to Africa_all_2008_2024_regions_batch_715.json
# Batch 716 with 25 regions saved to Africa_all_2008_2024_regions_batch_716.json
# Batch 717 with 25 regions saved to Africa_all_2008_2024_regions_batch_717.json
# Batch 718 with 25 regions saved to Africa_all_2008_2024_regions_batch_718.json
# Batch 719 with 25 regions saved to Africa_all_2008_2024_regions_batch_719.json
# Batch 720 with 25 regions saved to Africa_all_2008_2024_regions_batch_720.json
# Batch 721 with 25 regions saved to Africa_all_2008_2024_regions_batch_721.json
# Batch 722 with 25 regions saved to Africa_all_2008_2024_regions_batch_722.json
# Batch 723 with 25 regions saved to Africa_all_2008_2024_regions_batch_723.json
# Batch 724 with 25 regions saved to Africa_all_2008_2024_regions_batch_724.json
# Batch 725 with 25 regions saved to Africa_all_2008_2024_regions_batch_725.json
# Batch 726 with 25 regions saved to Africa_all_2008_2024_regions_batch_726.json
# Batch 727 with 25 regions saved to Africa_all_2008_2024_regions_batch_727.json
# Batch 728 with 25 regions saved to Africa_all_2008_2024_regions_batch_728.json
# Batch 729 with 25 regions saved to Africa_all_2008_2024_regions_batch_729.json
# Batch 730 with 25 regions saved to Africa_all_2008_2024_regions_batch_730.json
# Batch 731 with 25 regions saved to Africa_all_2008_2024_regions_batch_731.json
# Batch 732 with 25 regions saved to Africa_all_2008_2024_regions_batch_732.json
# Batch 733 with 25 regions saved to Africa_all_2008_2024_regions_batch_733.json
# Batch 734 with 25 regions saved to Africa_all_2008_2024_regions_batch_734.json
# Batch 735 with 25 regions saved to Africa_all_2008_2024_regions_batch_735.json
# Batch 736 with 25 regions saved to Africa_all_2008_2024_regions_batch_736.json
# Batch 737 with 25 regions saved to Africa_all_2008_2024_regions_batch_737.json
# Batch 738 with 25 regions saved to Africa_all_2008_2024_regions_batch_738.json
# Batch 739 with 25 regions saved to Africa_all_2008_2024_regions_batch_739.json
# Batch 740 with 25 regions saved to Africa_all_2008_2024_regions_batch_740.json
# Batch 741 with 25 regions saved to Africa_all_2008_2024_regions_batch_741.json
# Batch 742 with 25 regions saved to Africa_all_2008_2024_regions_batch_742.json
# Batch 743 with 25 regions saved to Africa_all_2008_2024_regions_batch_743.json
# Batch 744 with 25 regions saved to Africa_all_2008_2024_regions_batch_744.json
# Batch 745 with 25 regions saved to Africa_all_2008_2024_regions_batch_745.json
# Batch 746 with 25 regions saved to Africa_all_2008_2024_regions_batch_746.json
# Batch 747 with 25 regions saved to Africa_all_2008_2024_regions_batch_747.json
# Batch 748 with 25 regions saved to Africa_all_2008_2024_regions_batch_748.json
# Batch 749 with 25 regions saved to Africa_all_2008_2024_regions_batch_749.json
# Batch 750 with 25 regions saved to Africa_all_2008_2024_regions_batch_750.json
# Batch 751 with 25 regions saved to Africa_all_2008_2024_regions_batch_751.json
# Batch 752 with 25 regions saved to Africa_all_2008_2024_regions_batch_752.json
# Batch 753 with 25 regions saved to Africa_all_2008_2024_regions_batch_753.json
# Batch 754 with 25 regions saved to Africa_all_2008_2024_regions_batch_754.json
# Batch 755 with 25 regions saved to Africa_all_2008_2024_regions_batch_755.json
# Batch 756 with 25 regions saved to Africa_all_2008_2024_regions_batch_756.json
# Batch 757 with 25 regions saved to Africa_all_2008_2024_regions_batch_757.json
# Batch 758 with 13 regions saved to Africa_all_2008_2024_regions_batch_758.json

# %%
# years = pd.DataFrame({'year': range(2008, 2025)})
# data['key'] = 1
# years['key'] = 1

# data = pd.merge(data, years, on='key', how='outer').drop('key', axis=1)
# data['time_start'] = data['year'].astype(str) + '0101'
# data['time_end'] = data['year'].astype(str) + '1231'
# data['download_command'] = data.apply(lambda row: f"grid_{row.name}|{row['lon_min']},{row['lat_min']}|{row['lon_max']},{row['lat_max']}|14|{row['time_start']}|12", axis=1)
# data.head()

data['download_command'] = data.apply(lambda row: f"grid_{row.name}|{row['lon_min']},{row['lat_min']}|{row['lon_max']},{row['lat_max']}|14|20080101|12", axis=1)

# %%
global_map = gpd.read_file("/nas/houce/country_boundary/ne_110m_admin_0_countries.geojson")
africa_map = global_map[global_map['CONTINENT'] == 'Africa']

# %%
from shapely.geometry import Polygon

polygons = data.apply(
    lambda row: Polygon([
        (row['lon_min'], row['lat_min']),
        (row['lon_max'], row['lat_min']),
        (row['lon_max'], row['lat_max']),
        (row['lon_min'], row['lat_max']),
        (row['lon_min'], row['lat_min'])
    ]),
    axis=1
)

data_gpd = gpd.GeoDataFrame(data, geometry=polygons, crs="EPSG:4326")
data_gpd.to_csv("/nas/houce/global_slum/RS_download_data/human_settlement_grid_cells_deg_05_with_geometry.csv", index=False)

# %%
africa_data_gpd = data_gpd.sjoin(africa_map[['CONTINENT', 'SOVEREIGNT','geometry']], how='inner', predicate='intersects')

# %%
for i in range(0, len(africa_data_gpd), 25):
    batch = africa_data_gpd.iloc[i:i+25]
    np.savetxt(f'/nas/houce/SGDownload/download_commands/africa_download_commands_part_{i//25 + 1}.txt', batch['download_command'].values, fmt='%s')

# %%
# np.savetxt('/nas/houce/SGDownload/africa_download_commands.txt', africa_data_gpd['download_command'].values, fmt='%s')

# %%
# download_files = pd.read_json("/nas/houce/Landsat_30m/metadata/metadata/All_exist_slum.json").T.reset_index().rename(columns={'index':'grid_id'})
# download_files['time_start'] = pd.to_datetime(download_files['time_start'], format='mixed').dt.strftime('%Y%m%d')
# download_files['time_end'] = pd.to_datetime(download_files['time_end'], format='mixed').dt.strftime('%Y%m%d')

# download_files['download_command'] = download_files.apply(lambda row: f"{row['grid_id']}|{row['lon_min']},{row['lat_min']}|{row['lon_max']},{row['lat_max']}|14|{row['time_start']}|6", axis=1)
# # download_files['download_command'].to_csv('download_commands.txt', index=False, header=False)
# np.savetxt('download_commands.txt', download_files['download_command'].values, fmt='%s')
